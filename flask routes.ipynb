# %%
html lang="en"><head>
        <title>title | Profile</title>
        <!-- Required meta tags -->
        <meta charset="utf-8">
        <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">

        <!-- Bootstrap CSS -->
        <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.3.1/css/bootstrap.min.css" integrity="sha384-ggOyR0iXCbMQv3Xipma34MD+dH/1fQ784/j6cY/iJTQUOhcWr7x9JvoRxT2MZw1T" crossorigin="anonymous">
        <link rel="stylesheet" href="/static/css/main.css">
    </head>
    <body>

        <header>
            <nav class="navbar navbar-expand-sm navbar-dark bg-dark">
    <a class="navbar-brand" href="/">Fakebook</a>
    <button class="navbar-toggler d-lg-none" type="button" data-toggle="collapse" data-target="#collapsibleNavId" aria-controls="collapsibleNavId" aria-expanded="true" aria-label="Toggle navigation">
        <span class="navbar-toggler-icon"></span>
    </button>
    <div class="navbar-collapse collapse show" id="collapsibleNavId" style="">
        <ul class="navbar-nav mr-auto mt-2 mt-lg-0">
            <li class="nav-item active">
                <a class="nav-link" href="/">Home <span class="sr-only">(current)</span></a>
            </li>
            
            <li class="nav-item dropdown">
                <a class="nav-link dropdown-toggle" href="#" id="dropdownId" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">Shop</a>
                <div class="dropdown-menu" aria-labelledby="dropdownId">
                    <a class="dropdown-item" href="/shop/">Products</a>
                    <a class="dropdown-item" href="/shop/cart">
                        Cart
                        <span class="float-right badge badge-pill badge-secondary"> 0 </span>
                    </a>
                </div>
            </li>
            <li class="nav-item">
                <a class="nav-link" href="/contact">Contact</a>
            </li>
        </ul>
        <ul class="navbar-nav ml-auto">
            
                <li class="nav-item">
                    <a href="/authentication/login" class="nav-link">Login</a>
                </li>
                <li class="nav-item">
                    <a href="/authentication/register" class="nav-link">Register</a>
                </li>
            
        </ul>
    </div>
</nav>
        </header>

        <main class="container">

            
                
            


            
    <h3>Shop</h3>
    <hr>
​
    <div class="card-deck">
        
            <div class="col-4">
                <div class="card">
                    <div class="card-header">
                        <h6>
                            AirMax Moscow
                            <span class="float-right">$199.99</span>
                        </h6>
                    </div>
                    <div class="card-body">
                        <img class="card-img-top" src="https://files.stripe.com/links/MDB8YWNjdF8xSkNVZVpJbmJlTnlCRThhfGZsX3Rlc3RfRDFudUZJNFNpV1NocnlkQ2ZUalhuQjNm00sSkffBfK" alt="AirMax Moscow">
                        <a class="btn btn-success btn-block" style="margin-top: 10px;" href="/shop/cart/add?id=16">Add to cart</a>
                        <p class="card-text" style="margin-top: 10px;">Third product description</p>
                    </div>
                </div>
            </div>
        
            <div class="col-4">
                <div class="card">
                    <div class="card-header">
                        <h6>
                            GoFly Ease
                            <span class="float-right">$99.99</span>
                        </h6>
                          Air Max 90  Moscow 
                                           
                                           
                                                <span class="float-right>100.00</span>

                    </div>
                    <div class="card-body">
                       
                    </div>
                </div>
            </div>
        
            <div class="col-4">
                <div class="card">
                    <div class="card-header">
                        <h6>
                            Marty McFly
                            <span class="float-right">$499.99</span>
                        </h6>
                        Air-Moscow
                        < <span class="float-right">$167.99</span>

                    </div>
                    <div class="card-body">
                        <img class="card-img-top" src="https://files.stripe.com/links/MDB8YWNjdF8xSkNVZVpJbmJlTnlCRThhfGZsX3Rlc3RfaGlLaGs3eXhHelVEVUt4Z1hjeUx5NUtv001v8BKXyd" alt="Marty McFly">
                        <a class="btn btn-success btn-block" style="margin-top: 10px;" href="/shop/cart/add?id=18">Add to cart</a>
                        <p class="card-text" style="margin-top: 10px;">These are the shoes Marty wore in Back II The Future</p>
                    </div>
                </div>
            </div>
        
    </div>
        

        </main>

        <footer class="bg-dark text-light">
            <div class="container">
    <div class="row content-spacing">
        <div class="col-md-3">
            <h5>Page Links</h5>
            <hr class="border-light">
            <ul class="list-unstyled">
                <li class="list-item"><a class="text-light" href="/">Home</a></li>
                
                <li class="list-item"><a class="text-light" href="/contact">Contact</a></li>
            </ul>
        </div>
        <div class="col-md-3"></div>
        <div class="col-md-3"></div>
        <div class="col-md-3"></div>
    </div>
</div>
        </footer>

        <!-- Optional JavaScript -->
        <!-- jQuery first, then Popper.js, then Bootstrap JS -->
        
            <script src="https://code.jquery.com/jquery-3.3.1.min.js"></script>
            <script src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.14.7/umd/popper.min.js" integrity="sha384-UO2eT0CpHqdSJQ6hJty5KVphtPhzWj9WO1clHTMGa3JDZwrnQq4sF86dIHNDz0W1" crossorigin="anonymous"></script>
            <script src="https://stackpath.bootstrapcdn.com/bootstrap/4.3.1/js/bootstrap.min.js" integrity="sha384-JjSmVgyd0p3pXB1rRibZUAYoIIy6OrQ6VrjIEaFf/nJGzIxFDsf4x0xIM+B07jRM" crossorigin="anonymous"></script>
            <script src="https://cdnjs.cloudflare.com/ajax/libs/moment.js/2.29.1/moment-with-locales.min.js" integrity="sha512-LGXaggshOkD/at6PFNcp2V2unf9LzFq6LE+sChH7ceMTDP0g2kn6Vxwgg7wkPP7AAtX+lmPqPdxB47A0Nz0cMQ==" crossorigin="anonymous"></script>
<script>
moment.locale("en");
function flask_moment_render(elem) {
    const timestamp = moment(elem.dataset.timestamp);
    const func = elem.dataset.function;
    const format = elem.dataset.format;
    const timestamp2 = elem.dataset.timestamp2;
    const no_suffix = elem.dataset.nosuffix;
    const units = elem.dataset.units;
    let args = [];
    if (format)
        args.push(format);
    if (timestamp2)
        args.push(moment(timestamp2));
    if (no_suffix)
        args.push(no_suffix);
    if (units)
        args.push(units);
    elem.textContent = timestamp[func].apply(timestamp, args);
    elem.classList.remove('flask-moment');
    elem.style.display = "";
}
function flask_moment_render_all() {
    const moments = document.querySelectorAll('.flask-moment');
    moments.forEach(function(moment) {
        flask_moment_render(moment);
        const refresh = moment.dataset.refresh;
        if (refresh) {
            (function(elem, interval) {
                setInterval(function() {
                    flask_moment_render(elem);
                }, interval);
            })(moment, refresh);
        }
    })
}
document.addEventListener("DOMContentLoaded", flask_moment_render_all);
</script>
        
    
</body></html>



                        <form >
                            <div class="form-group" >
                                <div class="row" >
                                    <div class="col-md-10" >
                                        <input class="form-control" type="text" name='body' placeholder="Your blog post here..." />
                                    </div >
                                    <div class="col-md-2" >
                                        <input class="btn btn-info btn-block" type="submit" value="Post" />
                                    </div >
                                </div >
                            </div >
                        </form>

                        @app.route("/about")
                        def contacts():
                        return render_template("contact.html")

                        basedir= os .path.abspath.(os.path dirname__name))
                        from config import config
                        from flask import flask
                        class config.
                        app = Flask(.....name.....)
                        app.config.from object(config)
                        print(app.config)

                        from app imports routes

                        flask_app=run.property
                        FLASK_ENV= "devlopment"
                        <form >
                            <div class="form-group" >
                                <div class="row" >
                                    <div class="col-md-10" >
                                        <input class="form-control" type="text" name='body' placeholder="Your blog post here..." />
                                    </div >
                                    <div class="col-md-2" >
                                        <input class="btn btn-info btn-block" type="submit" value="Post" />
                                    </div >
                                </div >
                            </div >
                        </form>
